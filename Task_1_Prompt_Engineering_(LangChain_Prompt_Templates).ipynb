# %% [markdown]
# <a href="https://colab.research.google.com/github/Truptinaikwadi/IN226037202-ASSIGNMENT-GenAI-Prompt-Engineering/blob/main/Task_1_Prompt_Engineering_(LangChain_Prompt_Templates).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assignment: Mastering Prompt Templates in LangChain**

# %% [markdown]
# **Objective**
#
#
# Build dynamic and reusable prompt systems using LangChain instead of hardcoded prompts.

# %%
# !pip install -U langchain

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate

# %% [markdown]
# Task 1: Replace Hardcoded Prompts

# %%
template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

output = template.format(topic="AI")
print(output)

# %% [markdown]
# Task 2: Multi-Input Prompt System

# %%
template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

print(template.format(topic="AI", audience="beginners", tone="friendly"))
print(template.format(topic="Python", audience="kids", tone="fun"))
print(template.format(topic="Deep Learning", audience="engineers", tone="technical"))

# %% [markdown]
# Task 3: Prompt Variations Engine

# %%
teaching = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

storytelling = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching.format(topic=topic))
print(interview.format(topic=topic))
print(storytelling.format(topic=topic))

# %% [markdown]
# Task 4: ChatPromptTemplate System

# %%
chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {role}."),
    ("user", "Explain {topic}")
])

messages = chat_template.format_messages(
    role="teacher",
    topic="Neural Networks"
)

print(messages)

# %% [markdown]
# Task 5: Input Validation Layer

# %%
def validate_inputs(audience, tone):
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        audience = "beginner"

    if tone not in valid_tone:
        tone = "formal"

    return audience, tone

# %% [markdown]
# Task 6: Prompt Generator App

# %%
def generate_prompt(topic, audience, tone, style):
    audience, tone = validate_inputs(audience, tone)

    template = PromptTemplate(
        input_variables=["topic", "audience", "tone", "style"],
        template="Explain {topic} for {audience} in a {tone} {style} style"
    )

    return template.format(
        topic=topic,
        audience=audience,
        tone=tone,
        style=style
    )

print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))

# %% [markdown]
# Task 7: Template Reusability Test

# %%
template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} simply"
)

topics = ["AI", "Python", "SQL", "Cloud Computing", "Machine Learning"]

for t in topics:
    print(template.format(topic=t))
